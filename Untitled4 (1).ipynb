# %%
#Importing the modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib_inline
import seaborn as sns

# %%
#load the data
df=pd.read_excel(r'C:\Users\pc\Downloads\_Responses.Final.xlsx',)
df
# Out:
#                   Timestamp              Name                           Email  \
# 0   2024-03-25 15:36:49.178  Hamzah Dad Khan         hamzah.khan619@gmail.com
# 1   2024-03-25 15:41:14.461     Ayesha Amjad       ayesha.sabeen198@gmail.com
# 2   2024-03-25 15:43:43.546    Syeda Hussaini  syedahafsaalhussaini@gmail.com
# 3   2024-03-25 15:58:26.115      Anoosha Arif        anooshaarif123@gmail.com
# 4   2024-03-25 18:06:40.511     Alisha Zehra         alishazehra933@gmail.com
# ..                      ...               ...                             ...
# 103 2024-04-30 23:55:45.827    Syed Ali Raza        ssyedaliraza114@gmail.com
# 104 2024-05-01 00:33:27.204   Moattar Fatima        moattar13fatima@gmail.com
# 105 2024-05-01 07:54:02.749      Rumaisa Khan      momin.inside.out@gmail.com
# 106 2024-05-01 08:49:29.862      Zahra Akbar          zahraakbar034@gmail.com
# 107 2024-05-01 09:16:22.255      Ramsha Ahsan    pc4464.ramshaahsan@gmail.com
#
# ...

# %%
#comparison between first-year students with their decision
a=df[df['Year']=='1st Year']
sns.set(rc={'figure.figsize':(25,5)})
ax=sns.countplot(data=a,x='Year',hue='Decision')


for bars in ax.containers:
    ax.bar_label(bars)

# %%
#comparing the dream degree and the decision
a=df[df['Dream Degree']=='MBBS']
sns.set(rc={'figure.figsize':(25,5)})
ax=sns.countplot(data=a,x='Dream Degree',hue='Decision')


for bars in ax.containers:
    ax.bar_label(bars)

# %%
#Comparing biotechnology and their decision
a=df[df['Dream Degree']=='Biotechnology']
sns.set(rc={'figure.figsize':(25,5)})
ax=sns.countplot(data=a,x='Dream Degree',hue='Decision')


for bars in ax.containers:
    ax.bar_label(bars)

# %%
#Factors Vs Dream Degree
a=df[df['Dream Degree']=='MBBS']
sns.set(rc={'figure.figsize':(25,5)})
ax=sns.countplot(data=a,x='Factors',hue='Decision')


for bars in ax.containers:
    ax.bar_label(bars)

# %%
#value count of dream degree
a=df['Dream Degree']
a.iloc[0:109].value_counts()
# Out:
# Dream Degree
# MBBS             46
# Biotechnology    23
# BDS              14
# Pharmacy          7
# nutrition         3
# IT                2
# BBA               2
# Dpt               1
# Psychology        1
# Astrophysics      1
# Food Science      1
# Chemical Eng      1
# Psychology        1
# Army              1
# Business          1
# Pharmacy          1
# Psychologist      1
# Bs nursing        1
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 14 columns):
#  #   Column                                                                                                                                       Non-Null Count  Dtype
# ---  ------                                                                                                                                       --------------  -----
#  0   Timestamp                                                                                                                                    108 non-null    datetime64[ns]
#  1   Name                                                                                                                                         106 non-null    object
#  2   Email                                                                                                                                        101 non-null    object
# ...

# %%
df.head(10)
# Out:
#                 Timestamp               Name                           Email  \
# 0 2024-03-25 15:36:49.178   Hamzah Dad Khan         hamzah.khan619@gmail.com
# 1 2024-03-25 15:41:14.461      Ayesha Amjad       ayesha.sabeen198@gmail.com
# 2 2024-03-25 15:43:43.546     Syeda Hussaini  syedahafsaalhussaini@gmail.com
# 3 2024-03-25 15:58:26.115       Anoosha Arif        anooshaarif123@gmail.com
# 4 2024-03-25 18:06:40.511      Alisha Zehra         alishazehra933@gmail.com
# 5 2024-03-25 18:10:47.118          Taha khan              tk986033@gmail.com
# 6 2024-03-25 18:45:42.103     Malaika saleem      malaikasaleem404@gmail.com
# 7 2024-03-25 19:33:30.983  Muhammad Ibrahim        ibrahimaftab658@gmail.com
# 8 2024-03-25 19:59:09.942            Khizra           khizragull37@gmail.com
# 9 2024-03-26 10:16:02.047       Hifza fatima           naazhifza54@gmail.com
#
#    Gender Age          Level      Year  \
# 0    Male  20  Undergraduate  2nd Year
# 1  Female  20  Undergraduate  2nd Year
# ...

# %%
df['Factors'].describe()
# Out:
# count                                               108
# unique                                                3
# top       Biotechnology being the last good option left
# freq                                                 53
# Name: Factors, dtype: object

# %%
#genders
sns.set(rc={'figure.figsize':(10,5)})
ax=sns.countplot(x='Gender',data=df)


for bars in ax.containers:
    ax.bar_label(bars)

# %%
#factors Vs d
sns.set(rc={'figure.figsize':(25,5)})
ax=sns.countplot(data=df,x='Factors',hue='Decision')


for bars in ax.containers:
    ax.bar_label(bars)

# %%
ax=df['Age'].value_counts().plot(kind='pie')

for bars in ax.containers:
    ax.bar_label(pie)

# %%
sns.set(rc={'figure.figsize':(20,5)})
ax=sns.countplot(data=df,x='Age',hue='Decision')


for bars in ax.containers:
    ax.bar_label(bars)

# %%
sns.set(rc={'figure.figsize':(25,5)})
ax=sns.countplot(data=df,x='Dream Degree',hue='Decision')



for bars in ax.containers:
    ax.bar_label(bars)

# %%
sns.set(rc={'figure.figsize':(15,5)})
ax=sns.countplot(data=df,x='Year',hue='Decision')


for bars in ax.containers:
    ax.bar_label(bars)
